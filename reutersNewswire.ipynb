# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from tensorflow.keras.datasets import reuters

# %%
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %% [markdown]
# ## Decoding back to word

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()]
)
decoded_newswire = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]]
    #0, 1, 2 are reserved. 0 = padding, 1 = start of sequence, 2 = unknown
)

# %%
train_labels[10]
# Out:
# 3

# %%
decoded_newswire
# Out:
# '? ? ? said as a result of its december acquisition of space co it expects earnings per share in 1987 of 1 15 to 1 30 dlrs per share up from 70 cts in 1986 the company said pretax net should rise to nine to 10 mln dlrs from six mln dlrs in 1986 and rental operation revenues to 19 to 22 mln dlrs from 12 5 mln dlrs it said cash flow per share this year should be 2 50 to three dlrs reuter 3'

# %%
reverse_word_index
# Out:
# {10996: 'mdbl',
#  16260: 'fawc',
#  12089: 'degussa',
#  8803: 'woods',
#  13796: 'hanging',
#  20672: 'localized',
#  20673: 'sation',
#  20675: 'chanthaburi',
#  10997: 'refunding',
#  8804: 'hermann',
#  20676: 'passsengers',
#  20677: 'stipulate',
#  8352: 'heublein',
#  20713: 'screaming',
#  16261: 'tcby',
#  185: 'four',
#  1642: 'grains',
#  20680: 'broiler',
#  12090: 'wooden',
#  1220: 'wednesday',
#  13797: 'highveld',
#  7593: 'duffour',
#  20681: '0053',
#  3914: 'elections',
#  2563: '270',
#  3551: '271',
#  5113: '272',
#  3552: '273',
#  3400: '274',
#  7975: 'rudman',
#  3401: '276',
#  3478: '277',
#  3632: '278',
#  4309: '279',
#  9381: 'dormancy',
#  7247: 'errors',
#  3086: 'deferred',
#  20683: 'sptnd',
#  8805: 'cooking',
#  20684: 'stratabit',
#  16262: 'designing',
#  20685: 'metalurgicos',
#  13798: 'databank',
#  20686: '300er',
#  20687: 'shocks',
#  7972: 'nawg',
#  20688: 'tnta',
#  20689: 'perforations',
#  2891: 'affiliates',
#  20690: '27p',
# ...

# %%
word_index
# Out:
# {'mdbl': 10996,
#  'fawc': 16260,
#  'degussa': 12089,
#  'woods': 8803,
#  'hanging': 13796,
#  'localized': 20672,
#  'sation': 20673,
#  'chanthaburi': 20675,
#  'refunding': 10997,
#  'hermann': 8804,
#  'passsengers': 20676,
#  'stipulate': 20677,
#  'heublein': 8352,
#  'screaming': 20713,
#  'tcby': 16261,
#  'four': 185,
#  'grains': 1642,
#  'broiler': 20680,
#  'wooden': 12090,
#  'wednesday': 1220,
#  'highveld': 13797,
#  'duffour': 7593,
#  '0053': 20681,
#  'elections': 3914,
#  '270': 2563,
#  '271': 3551,
#  '272': 5113,
#  '273': 3552,
#  '274': 3400,
#  'rudman': 7975,
#  '276': 3401,
#  '277': 3478,
#  '278': 3632,
#  '279': 4309,
#  'dormancy': 9381,
#  'errors': 7247,
#  'deferred': 3086,
#  'sptnd': 20683,
#  'cooking': 8805,
#  'stratabit': 20684,
#  'designing': 16262,
#  'metalurgicos': 20685,
#  'databank': 13798,
#  '300er': 20686,
#  'shocks': 20687,
#  'nawg': 7972,
#  'tnta': 20688,
#  'perforations': 20689,
#  'affiliates': 2891,
#  '27p': 20690,
# ...

# %% [markdown]
# ## Preparing Data

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, j] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)


# def to_one_hot(labels, dimension=46):
#     results = np.zeros((len(labels), dimension))
#     for i, label in enumerate(labels):
#         results[i, label] = 1.
#     return results
    
# y_train = to_one_hot(train_labels)
# y_test = to_one_hot(test_labels)

# %% [markdown]
# ## Building Models

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(46, activation="softmax")
])

# %%
model.compile(optimizer="rmsprop", 
             loss = "categorical_crossentropy", 
             metrics = ["accuracy"])

# %% [markdown]
# #### Setting apart 1000 samples for validation set from training data

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %%
partial_x_train.shape
# Out:
# (7982, 10000)

# %%
partial_y_train.shape
# Out:
# (7982, 46)

# %%
history = model.fit(partial_x_train,
                   partial_y_train,
                   epochs=20,
                   batch_size=512,
                   validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.4349 - loss: 3.0159 - val_accuracy: 0.6200 - val_loss: 1.7865
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6598 - loss: 1.6003 - val_accuracy: 0.6990 - val_loss: 1.3990
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7362 - loss: 1.2212 - val_accuracy: 0.7370 - val_loss: 1.2178
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7818 - loss: 1.0053 - val_accuracy: 0.7620 - val_loss: 1.1010
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8178 - loss: 0.8407 - val_accuracy: 0.7740 - val_loss: 1.0189
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8460 - loss: 0.7175 - val_accuracy: 0.7890 - val_loss: 0.9691
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8702 - loss: 0.5908 - val_accuracy: 0.7950 - val_loss: 0.9371
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt 

loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label = "Training loss")
plt.plot(epochs, val_loss, "b", label = "Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo", label = "Training accuracy")
plt.plot(epochs, val_acc, "b", label = "Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %%
# models starts to overfit after epoch 9

# %%
model = keras.Sequential([
    layers.Dense(64, activation = "relu"),
    layers.Dense(64, activation = "relu"),
    layers.Dense(46, activation = "softmax")
])

model.compile(optimizer="rmsprop",
             loss="categorical_crossentropy",
             metrics=["accuracy"])

model.fit(x_train,
         y_train, 
         epochs=9,
          batch_size=512)

results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4365 - loss: 3.0675
# Epoch 2/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6693 - loss: 1.5543
# Epoch 3/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7369 - loss: 1.2027
# Epoch 4/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7877 - loss: 0.9846
# Epoch 5/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8269 - loss: 0.7982
# Epoch 6/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8600 - loss: 0.6558
# Epoch 7/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8849 - loss: 0.5410
# Epoch 8/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9036 - loss: 0.4629
# Epoch 9/9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9140 - loss: 0.3969
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7965 - loss: 0.8989

# %%
results
# Out:
# [0.9329970479011536, 0.7889581322669983]

# %% [markdown]
# #### Comparing to random baseline of 46 classes

# %%
import copy
test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
hits_array = np.array(test_labels) == np.array(test_labels_copy)
hits_array.mean()
# Out:
# 0.1772039180765806

# %% [markdown]
# ## Predicting based on New Data

# %%
# Calling the model’s predict method on new samples returns a class probability distribution 
# over all 46 topics for each sample.

# %%
predictions = model.predict(x_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# 1.0

# %%
np.argmax(predictions[0])
# Out:
# 3

# %%
# largest entry = predicted class (class with highest probability)
